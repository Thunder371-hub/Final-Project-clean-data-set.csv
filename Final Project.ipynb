# %%
# !pip install kaggle
from google.colab import files
files.upload()
# Out:
# ...
#      <input type="file" id="files-38c55d78-df3f-40fd-acea-c77055817cbb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-38c55d78-df3f-40fd-acea-c77055817cbb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d javagarm/movies-on-ott-platforms
# Out:
# Dataset URL: https://www.kaggle.com/datasets/javagarm/movies-on-ott-platforms
# License(s): CC0-1.0
# ...
#   0% 0.00/579k [00:00<?, ?B/s]
# 100% 579k/579k [00:00<00:00, 984MB/s]

# %%
# !unzip movies-on-ott-platforms.zip
# Out:
# Archive:  movies-on-ott-platforms.zip
#   inflating: MoviesOnStreamingPlatforms_updated.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("MoviesOnStreamingPlatforms_updated.csv")

# %%
df.head(45)
# Out:
#     ID                                 Title  Year  Age  IMDb Rotten Tomatoes  \
# 0    1                             Inception  2010  13+   8.8             87%
# 1    2                            The Matrix  1999  18+   8.7             87%
# 2    3                Avengers: Infinity War  2018  13+   8.5             84%
# 3    4                    Back to the Future  1985   7+   8.5             96%
# 4    5        The Good, the Bad and the Ugly  1966  18+   8.8             97%
# 5    6     Spider-Man: Into the Spider-Verse  2018   7+   8.4             97%
# 6    7                           The Pianist  2002  18+   8.5             95%
# 7    8                      Django Unchained  2012  18+   8.4             87%
# 8    9               Raiders of the Lost Ark  1981   7+   8.4             95%
# 9   10                  Inglourious Basterds  2009  18+   8.3             89%
# 10  11                           Taxi Driver  1976  18+   8.3             95%
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16744 entries, 0 to 16743
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               16744 non-null  int64
#  1   Title            16744 non-null  object
#  2   Year             16744 non-null  int64
#  3   Age              7354 non-null   object
#  4   IMDb             16173 non-null  float64
#  5   Rotten Tomatoes  5158 non-null   object
#  6   Netflix          16744 non-null  float64
#  7   Hulu             16744 non-null  int64
#  8   Prime Video      16744 non-null  int64
#  9   Disney+          16744 non-null  int64
#  10  Type             16744 non-null  int64
#  11  Directors        16018 non-null  object
#  12  Genres           16469 non-null  object
#  13  Country          16309 non-null  object
#  14  Language         16130 non-null  object
#  15  Runtime          16152 non-null  float64
# dtypes: float64(3), int64(6), object(7)
# ...

# %%
df.isnull().sum()
# Out:
# ID                     0
# Title                  0
# Year                   0
# Age                 9390
# IMDb                 571
# Rotten Tomatoes    11586
# Netflix                0
# Hulu                   0
# Prime Video            0
# Disney+                0
# Type                   0
# Directors            726
# Genres               275
# Country              435
# Language             614
# Runtime              592
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
num_cols = df.select_dtypes(include=['int64','float64']).columns
cat_cols = df.select_dtypes(include=['object']).columns

print("Numerical Columns:", num_cols)
print("Categorical Columns:", cat_cols)
# Out:
# Numerical Columns: Index(['ID', 'Year', 'IMDb', 'Netflix', 'Hulu', 'Prime Video', 'Disney+',
#        'Type', 'Runtime'],
#       dtype='object')
# Categorical Columns: Index(['Title', 'Age', 'Rotten Tomatoes', 'Directors', 'Genres', 'Country',
#        'Language'],
#       dtype='object')

# %%
for col in num_cols:
    df[col] = df[col].fillna(df[col].mean())

for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
df.isnull().sum()
# Out:
# ID                 0
# Title              0
# Year               0
# Age                0
# IMDb               0
# Rotten Tomatoes    0
# Netflix            0
# Hulu               0
# Prime Video        0
# Disney+            0
# Type               0
# Directors          0
# Genres             0
# Country            0
# Language           0
# Runtime            0
# dtype: int64

# %%
for col in num_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    df = df[(df[col] >= Q1 - 1.5 * IQR) & (df[col] <= Q3 + 1.5 * IQR)]

# %%
df.info()
df.head(30)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8466 entries, 4442 to 16211
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               8466 non-null   int64
#  1   Title            8466 non-null   object
#  2   Year             8466 non-null   int64
#  3   Age              8466 non-null   object
#  4   IMDb             8466 non-null   float64
#  5   Rotten Tomatoes  8466 non-null   object
#  6   Netflix          8466 non-null   float64
#  7   Hulu             8466 non-null   int64
#  8   Prime Video      8466 non-null   int64
#  9   Disney+          8466 non-null   int64
#  10  Type             8466 non-null   int64
#  11  Directors        8466 non-null   object
#  12  Genres           8466 non-null   object
#  13  Country          8466 non-null   object
#  14  Language         8466 non-null   object
#  15  Runtime          8466 non-null   float64
# dtypes: float64(3), int64(6), object(7)
# ...

# %%
df.describe(include='all')
# Out:
#                   ID             Title         Year   Age         IMDb  \
# count    8466.000000              8466  8466.000000  8466  8466.000000
# unique           NaN              8466          NaN     5          NaN
# top              NaN  Beneath Alcatraz          NaN   18+          NaN
# freq             NaN                 1          NaN  6860          NaN
# mean    10200.949090               NaN  2007.933144   NaN     5.689773
# std      3398.002652               NaN    10.341449   NaN     1.361597
# min      4443.000000               NaN  1976.000000   NaN     2.400000
# 25%      7235.250000               NaN  2005.000000   NaN     4.700000
# 50%     10081.500000               NaN  2012.000000   NaN     5.900000
# 75%     13118.750000               NaN  2015.000000   NaN     6.700000
# max     16212.000000               NaN  2020.000000   NaN     9.300000
#
#        Rotten Tomatoes  Netflix    Hulu  Prime Video  Disney+    Type  \
# ...

# %%
df.isnull().sum()
# Out:
# ID                 0
# Title              0
# Year               0
# Age                0
# IMDb               0
# Rotten Tomatoes    0
# Netflix            0
# Hulu               0
# Prime Video        0
# Disney+            0
# Type               0
# Directors          0
# Genres             0
# Country            0
# Language           0
# Runtime            0
# dtype: int64

# %%
df.head(40)
# Out:
#         ID                                             Title  Year  Age  IMDb  \
# 4442  4443                                         Airplane!  1980   7+   7.7
# 4447  4448                                         Lady Bird  2017  18+   7.4
# 4450  4451                                      The Big Sick  2017  18+   7.5
# 4452  4453                              The Man from Nowhere  2010  18+   7.8
# 4453  4454                                     Short Term 12  2013  18+   8.0
# 4457  4458                                     The Machinist  2004  18+   7.7
# 4459  4460  Dear Zachary: A Letter to a Son About His Father  2008  18+   8.6
# 4461  4462                               The Disaster Artist  2017  18+   7.4
# 4463  4464                                                Pi  1998  18+   7.4
# 4464  4465                                    The Lighthouse  2019  18+   7.6
# 4465  4466                                      The Farewell  2019   7+   7.6
# ...

# %%
df.to_csv("MoviesOnStreamingPlatforms_updated_cleaned.csv", index=False)

# %%
df.to_csv("MoviesOnStreamingPlatforms_updated_cleaned.csv")
from google.colab import files
files.download("MoviesOnStreamingPlatforms_updated_cleaned.csv")
